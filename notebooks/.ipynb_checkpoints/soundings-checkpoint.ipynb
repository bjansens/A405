# %%
from importlib import reload
import soundings.readsoundings
reload(soundings.readsoundings)
from soundings.readsoundings import readsound
import pandas as pd
from matplotlib import pyplot as plt

# %%
import glob
out=glob.glob('../*soundings/*december*txt')
sounding_dict=readsound(out[0])
dict_keys=list(sounding_dict.keys())
print(dict_keys[:3])
print(sounding_dict[dict_keys[0]].head())
# Out:
# [datetime.datetime(2015, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2015, 12, 1, 12, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2015, 12, 2, 0, 0, tzinfo=datetime.timezone.utc)]
#     pres  hght  temp  dwpt  relh      mixr  drct  sknt   thta   thte   thtv
# 0  993.0    22  11.2   7.8    80  6.696764   130    15  284.9  303.8  286.1
# 1  956.4   305 -13.3 -15.3    85  1.218065   140    24  263.2  266.6  263.4
# 2  918.4   610 -15.3 -16.6    89  1.138433   170    26  264.2  267.4  264.4
# 3  850.0  1192 -19.3 -20.0    94  0.921484   200    27  265.9  268.6  266.1
# 4  791.0  1723 -22.9 -23.3    97  0.741837   216    31  267.6  269.8  267.7

# %%
outfile='december.h5'
with pd.HDFStore(outfile,'w') as store:
    for key,value in sounding_dict.items():
        thetime=key.strftime("Y%Y_%b_%d_%HZ")
        store.put(thetime,value,format='table')

# %%
with pd.HDFStore(outfile,'r') as store:
    sounding=store['Y2015_Dec_17_00Z']
    print(sounding.loc[:5])
# Out:
#    pres  hght  temp  dwpt  relh      mixr  drct  sknt   thta   thte   thtv
# 0  1023    22 -24.5 -30.5    58  0.296107     0     0  247.0  247.9  247.1
# 1  1003   164 -14.3 -23.3    46  0.584890   334    13  258.6  260.3  258.7
# 2   996   216 -14.1 -29.1    27  0.347045   330    15  259.4  260.4  259.4
# 3   974   386 -14.3 -19.3    66  0.853895   329    14  260.8  263.2  260.9
# 4   928   752 -15.3 -19.8    68  0.858598   316    16  263.4  265.9  263.6
# 5   910   900 -13.5 -19.5    61  0.898487   311    20  266.7  269.4  266.9

# %%
# %matplotlib inline
m2km=1.e-3  #convert meters to km
plt.style.use('ggplot')
fig,ax=plt.subplots(1,1,figsize=(8,10))
ax.plot(sounding['temp'],sounding['hght']*m2km,label='temp')
ax.plot(sounding['dwpt'],sounding['hght']*m2km,label='dewpoint')
ax.legend()
out=ax.set(xlabel="temperature (K)",ylabel="height (km)",
      title ="December 2015 soundings, Iqaluit")
